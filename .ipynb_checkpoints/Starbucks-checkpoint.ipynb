# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt

# %matplotlib inline

warnings.filterwarnings(action='ignore')

# %%
# As i'm gonna find healthy drinks, so i decided to find them based on calories, carb, fat
data = pd.read_csv('starbucks-menu-nutrition-drinks.csv')
data.sort_index()
data = data.rename(columns={'Unnamed: 0': 'Drink_name',
                            'Calories': 'calories', 'Fat (g)': 'fat', 'Carb. (g)': 'carb'})
df = data.drop(['Protein', 'Sodium', 'Fiber (g)'], 1)
df
# Out:
#                                             Drink_name calories fat carb
# 0             Cool Lime Starbucks Refreshers™ Beverage       45   0   11
# 1                                     Ombré Pink Drink        -   -    -
# 2                                           Pink Drink        -   -    -
# 3       Strawberry Acai Starbucks Refreshers™ Beverage       80   0   18
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...       60   0   14
# ..                                                 ...      ...  ..  ...
# 172                                 Chocolate Smoothie      320   5   53
# 173                                Strawberry Smoothie      300   2   60
# 174                                         Ginger Ale        -   -    -
# 175                                          Lemon Ale        -   -    -
# 176                                  Orange Cream Soda        -   -    -
#
# [177 rows x 4 columns]

# %%
# I was worried about duplicated datas, but there's nothing to be worried about. they're same drinks with different flavers.

duplicated = pd.DataFrame(df[df.duplicated()] == "True")
duplicated = duplicated.drop(['Drink_name', 'calories', 'fat', 'carb'], 1)
duplicated_list = []
for item in duplicated.index:
    duplicated_list.append(df['Drink_name'][item])

pd.DataFrame(duplicated_list, columns=['Drink_name'])
# Out:
#                                     Drink_name
# 0       Iced Espresso Classics - Vanilla Latte
# 1         Iced Espresso Classics - Caffe Mocha
# 2   Iced Espresso Classics - Caramel Macchiato
# 3               Starbucks® Caramel Iced Coffee
# 4                Starbucks® Iced Coffee + Milk
# 5    Starbucks® Low Calorie Iced Coffee + Milk
# 6               Starbucks® Vanilla Iced Coffee
# 7            Tazo® Bottled Berry Blossom White
# 8                    Tazo® Bottled Black Mango
# 9               Tazo® Bottled Black with Lemon
# 10                  Tazo® Bottled Brambleberry
# 11                   Tazo® Bottled Giant Peach
# 12                  Tazo® Bottled Iced Passion
# 13                  Tazo® Bottled Lemon Ginger
# 14        Tazo® Bottled Organic Black Lemonade
# 15        Tazo® Bottled Organic Iced Black Tea
# 16        Tazo® Bottled Organic Iced Green Tea
# 17              Tazo® Bottled Plum Pomegranate
# 18                     Tazo® Bottled Tazoberry
# 19               Tazo® Bottled White Cranberry
# 20                       Iced Coffee with Milk
# 21                             Latte Macchiato

# %%
# cleaning non value datas, the reason why i deleted zero calorie, carb and fat drinks is that if they exist, they're not good for your health our aim is to find HEALTHY drinks
df = df.sort_values('calories')
df = df.drop(df[(df.calories == '-') | ((df.calories == '0')
                                        & (df.fat == '0') & (df.carb == '0'))].index)
# Haaaaaard coding:D

# %%
cols = ['carb', 'calories', 'fat']
df[cols] = df[cols].astype(float)
df = df.sort_values(by =['calories'], ascending = True)
df = df.reset_index()

# %%
selected = df.loc[(df['calories'] < 100) & (df['calories'] >= 30)]
selected
# Out:
#     index                                         Drink_name  calories  fat  \
# 9      34                     Teavana® Shaken Iced Green Tea      30.0  0.0
# 10     36            Teavana® Shaken Iced Passion Tango™ Tea      30.0  0.0
# 11     32                     Teavana® Shaken Iced Black Tea      30.0  0.0
# 12      0           Cool Lime Starbucks Refreshers™ Beverage      45.0  0.0
# 13    137              Starbucks Doubleshot® on Ice Beverage      45.0  1.0
# 14     72             Starbucks® Iced Coffee Light Sweetened      50.0  0.0
# 15     85               Tazo® Bottled Organic Iced Black Tea      60.0  0.0
# 16     71                     Starbucks® Iced Coffee Caramel      60.0  0.0
# 17     19                  Tazo® Bottled Berry Blossom White      60.0  0.0
# 18     77                  Tazo® Bottled Berry Blossom White      60.0  0.0
# 19     38               Teavana® Shaken Iced Peach Green Tea      60.0  0.0
# 20     27               Tazo® Bottled Organic Iced Black Tea      60.0  0.0
# 21      4  Very Berry Hibiscus Starbucks Refreshers™ Beve...      60.0  0.0
# 22     24                         Tazo® Bottled Iced Passion      70.0  0.0
# 23     35            Teavana® Shaken Iced Green Tea Lemonade      70.0  0.0
# 24    105                   Nitro Cold Brew with Sweet Cream      70.0  5.0
# 25     82                         Tazo® Bottled Iced Passion      70.0  0.0
# 26     33            Teavana® Shaken Iced Black Tea Lemonade      70.0  0.0
# 27     18                                   Shaken Sweet Tea      80.0  0.0
# 28      3     Strawberry Acai Starbucks Refreshers™ Beverage      80.0  0.0
# 29     55        Starbucks Refreshers™ Raspberry Pomegranate      90.0  0.0
# 30     56          Starbucks Refreshers™ Strawberry Lemonade      90.0  0.0
# 31     37   Teavana® Shaken Iced Passion Tango™ Tea Lemonade      90.0  0.0
#
#     carb
# 9    8.0
# 10   8.0
# 11   8.0
# 12  11.0
# 13   5.0
# 14  11.0
# 15  15.0
# 16  13.0
# 17  15.0
# 18  15.0
# 19  15.0
# 20  15.0
# 21  14.0
# 22  17.0
# 23  17.0
# 24   5.0
# 25  17.0
# 26  17.0
# 27  19.0
# 28  18.0
# 29  27.0
# 30  27.0
# 31  24.0

# %%
Scatter = selected.plot(figsize = (12,6),kind = 'scatter', x = 'Drink_name', y = 'calories', color = 'red')
plt.xticks(rotation=90)
label = ['Calories']
plt.legend(label, loc='upper center', fontsize = 12)
plt.show()
